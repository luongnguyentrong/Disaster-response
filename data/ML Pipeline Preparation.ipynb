# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\luong\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
pd.set_option('display.max_colwidth', None)

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table("clean_disaster_data", engine)

# %%
X = df["message"]
y = df.iloc[:, 4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier

# %%
pipeline = Pipeline([
    ('text_pipeline', Pipeline([
        ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
        ('tfidf_transformer', TfidfTransformer())
    ])) ,
    ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
pipeline_fitted = pipeline.fit(X_train, y_train)
# Out:
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
from sklearn.metrics import classification_report

# %%
y_prediction_train = pipeline_fitted.predict(X_test)

# %%
for idx, column in enumerate(y.columns.values):
    print("Target: ", column)
    print(classification_report(y_test[column], y_prediction_train[:, idx]))
    print("---" * 10)
# Out:
# Target:  related
#               precision    recall  f1-score   support
#
#            0       0.58      0.24      0.34      1527
#            1       0.80      0.95      0.87      4984
#            2       0.29      0.14      0.19        43
#
#     accuracy                           0.78      6554
#    macro avg       0.56      0.44      0.46      6554
# weighted avg       0.75      0.78      0.74      6554
#
# ------------------------------
# Target:  request
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      5432
#            1       0.77      0.55      0.64      1122
#
#     accuracy                           0.89      6554
#    macro avg       0.84      0.76      0.79      6554
# weighted avg       0.89      0.89      0.89      6554
#
# ------------------------------
# Target:  offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------
# Target:  aid_related
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80      3829
#            1       0.76      0.57      0.65      2725
#
#     accuracy                           0.74      6554
#    macro avg       0.75      0.72      0.72      6554
# weighted avg       0.75      0.74      0.74      6554
#
# ------------------------------
# Target:  medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      6008
#            1       0.60      0.27      0.38       546
#
#     accuracy                           0.92      6554
#    macro avg       0.77      0.63      0.67      6554
# weighted avg       0.91      0.92      0.91      6554
#
# ------------------------------
# Target:  medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6209
#            1       0.65      0.32      0.43       345
#
#     accuracy                           0.95      6554
#    macro avg       0.81      0.65      0.70      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ------------------------------
# Target:  search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6375
#            1       0.52      0.17      0.26       179
#
#     accuracy                           0.97      6554
#    macro avg       0.75      0.58      0.62      6554
# weighted avg       0.96      0.97      0.97      6554
#
# ------------------------------
# Target:  security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6432
#            1       0.31      0.04      0.07       122
#
#     accuracy                           0.98      6554
#    macro avg       0.65      0.52      0.53      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------
# Target:  military
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6348
#            1       0.59      0.32      0.42       206
#
#     accuracy                           0.97      6554
#    macro avg       0.78      0.66      0.70      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ------------------------------
# Target:  child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# ------------------------------
# Target:  water
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6137
#            1       0.75      0.62      0.68       417
#
#     accuracy                           0.96      6554
#    macro avg       0.86      0.80      0.83      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ------------------------------
# Target:  food
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5829
#            1       0.81      0.69      0.75       725
#
#     accuracy                           0.95      6554
#    macro avg       0.89      0.84      0.86      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ------------------------------
# Target:  shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5970
#            1       0.76      0.53      0.63       584
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.76      0.80      6554
# weighted avg       0.94      0.94      0.94      6554
#
# ------------------------------
# Target:  clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6447
#            1       0.67      0.34      0.45       107
#
#     accuracy                           0.99      6554
#    macro avg       0.83      0.67      0.72      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------
# Target:  money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6387
#            1       0.60      0.28      0.38       167
#
#     accuracy                           0.98      6554
#    macro avg       0.79      0.64      0.68      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ------------------------------
# Target:  missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6473
#            1       0.54      0.16      0.25        81
#
#     accuracy                           0.99      6554
#    macro avg       0.77      0.58      0.62      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------
# Target:  refugees
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6334
#            1       0.45      0.18      0.26       220
#
#     accuracy                           0.97      6554
#    macro avg       0.71      0.59      0.62      6554
# weighted avg       0.95      0.97      0.96      6554
#
# ------------------------------
# Target:  death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6248
#            1       0.75      0.41      0.53       306
#
#     accuracy                           0.97      6554
#    macro avg       0.86      0.70      0.76      6554
# weighted avg       0.96      0.97      0.96      6554
#
# ------------------------------
# Target:  other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      5684
#            1       0.51      0.13      0.21       870
#
#     accuracy                           0.87      6554
#    macro avg       0.70      0.56      0.57      6554
# weighted avg       0.83      0.87      0.83      6554
#
# ------------------------------
# Target:  infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6137
#            1       0.42      0.10      0.16       417
#
#     accuracy                           0.93      6554
#    macro avg       0.68      0.55      0.56      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ------------------------------
# Target:  transport
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6224
#            1       0.67      0.19      0.30       330
#
#     accuracy                           0.95      6554
#    macro avg       0.81      0.59      0.64      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ------------------------------
# Target:  buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6222
#            1       0.67      0.40      0.50       332
#
#     accuracy                           0.96      6554
#    macro avg       0.82      0.70      0.74      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ------------------------------
# Target:  electricity
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6414
#            1       0.67      0.32      0.43       140
#
#     accuracy                           0.98      6554
#    macro avg       0.83      0.66      0.71      6554
# weighted avg       0.98      0.98      0.98      6554
#
# ------------------------------
# Target:  tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6510
#            1       0.33      0.05      0.08        44
#
#     accuracy                           0.99      6554
#    macro avg       0.66      0.52      0.54      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------
# Target:  hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6481
#            1       0.25      0.08      0.12        73
#
#     accuracy                           0.99      6554
#    macro avg       0.62      0.54      0.56      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------
# Target:  shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6519
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------
# Target:  aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6481
#            1       0.24      0.07      0.11        73
#
#     accuracy                           0.99      6554
#    macro avg       0.61      0.53      0.55      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------
# Target:  other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6277
#            1       0.33      0.10      0.16       277
#
#     accuracy                           0.95      6554
#    macro avg       0.65      0.55      0.57      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ------------------------------
# Target:  weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      4726
#            1       0.85      0.66      0.75      1828
#
#     accuracy                           0.87      6554
#    macro avg       0.87      0.81      0.83      6554
# weighted avg       0.87      0.87      0.87      6554
#
# ------------------------------
# Target:  floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6021
#            1       0.88      0.52      0.65       533
#
#     accuracy                           0.96      6554
#    macro avg       0.92      0.76      0.81      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ------------------------------
# Target:  storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      5940
#            1       0.76      0.50      0.60       614
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.74      0.78      6554
# weighted avg       0.93      0.94      0.93      6554
#
# ------------------------------
# Target:  fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6482
#            1       0.51      0.29      0.37        72
#
#     accuracy                           0.99      6554
#    macro avg       0.75      0.64      0.68      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ------------------------------
# Target:  earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5932
#            1       0.89      0.78      0.83       622
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.88      0.91      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ------------------------------
# Target:  cold
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6430
#            1       0.70      0.39      0.50       124
#
#     accuracy                           0.99      6554
#    macro avg       0.84      0.69      0.74      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ------------------------------
# Target:  other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6217
#            1       0.43      0.14      0.21       337
#
#     accuracy                           0.95      6554
#    macro avg       0.69      0.57      0.59      6554
# weighted avg       0.93      0.95      0.93      6554
#
# ------------------------------
# Target:  direct_report
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5301
#            1       0.72      0.50      0.59      1253
#
#     accuracy                           0.87      6554
#    macro avg       0.81      0.73      0.76      6554
# weighted avg       0.86      0.87      0.86      6554
#
# ------------------------------

# %% [markdown]
# ### 6. Improve your model

# %% [markdown]
# Add another feature named __StartingVerb__

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %% [markdown]
# Create a new pipeline which union this new feature before putting it into the classifier algorithm

# %%
pipeline_new = Pipeline([
    ('feature', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
            ('tfidf_transformer', TfidfTransformer())
        ])),
        ('starting_verb', StartingVerbExtractor()) 
    ])) ,
    ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
])

# %% [markdown]
# Use grid search to find better parameters.

# %%
parameters =  {
    'classifier__estimator__learning_rate': [0.5, 1.0],
    'classifier__estimator__n_estimators': [10, 20]
}

cv = GridSearchCV(pipeline_new, param_grid=parameters, cv=5, n_jobs=-1, verbose=3) 

cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature',
#                                         FeatureUnion(transformer_list=[('text_pipeline',
#                                                                         Pipeline(steps=[('count_vectorizer',
#                                                                                          CountVectorizer(tokenizer=<function tokenize at 0x0000020B249A5940>)),
#                                                                                         ('tfidf_transformer',
#                                                                                          TfidfTransformer())])),
#                                                                        ('starting_verb',
#                                                                         StartingVerbExtractor())])),
#                                        ('classifier',
#                                         MultiOutputClassifier(estimator=AdaBoostClassifier()))]),
#              n_jobs=-1,
#              param_grid={'classifier__estimator__learning_rate': [0.5, 1.0],
#                          'classifier__estimator__n_estimators': [10, 20]},
#              verbose=3)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_prediction_train = cv.predict(X_test)

# %%
for idx, column in enumerate(y.columns.values):
    print("Target: ", column)
    print(classification_report(y_test[column], y_prediction_train[:, idx]))
    print("---" * 10)
# Out:
# Target:  related
#               precision    recall  f1-score   support
#
#            0       0.55      0.19      0.28      4577
#            1       0.79      0.95      0.86     14954
#            2       0.38      0.07      0.12       131
#
#     accuracy                           0.77     19662
#    macro avg       0.57      0.40      0.42     19662
# weighted avg       0.73      0.77      0.72     19662
#
# ------------------------------
# Target:  request
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     16348
#            1       0.77      0.50      0.61      3314
#
#     accuracy                           0.89     19662
#    macro avg       0.84      0.74      0.77     19662
# weighted avg       0.88      0.89      0.88     19662
#
# ------------------------------
# Target:  offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19565
#            1       0.33      0.03      0.06        97
#
#     accuracy                           0.99     19662
#    macro avg       0.66      0.52      0.53     19662
# weighted avg       0.99      0.99      0.99     19662
#
# ------------------------------
# Target:  aid_related
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80     11532
#            1       0.75      0.56      0.64      8130
#
#     accuracy                           0.74     19662
#    macro avg       0.74      0.71      0.72     19662
# weighted avg       0.74      0.74      0.73     19662
#
# ------------------------------
# Target:  medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     18122
#            1       0.65      0.27      0.39      1540
#
#     accuracy                           0.93     19662
#    macro avg       0.80      0.63      0.67     19662
# weighted avg       0.92      0.93      0.92     19662
#
# ------------------------------
# Target:  medical_products
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18683
#            1       0.71      0.31      0.44       979
#
#     accuracy                           0.96     19662
#    macro avg       0.84      0.65      0.71     19662
# weighted avg       0.95      0.96      0.95     19662
#
# ------------------------------
# Target:  search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     19122
#            1       0.65      0.25      0.36       540
#
#     accuracy                           0.98     19662
#    macro avg       0.81      0.62      0.67     19662
# weighted avg       0.97      0.98      0.97     19662
#
# ------------------------------
# Target:  security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     19311
#            1       0.42      0.07      0.12       351
#
#     accuracy                           0.98     19662
#    macro avg       0.70      0.53      0.56     19662
# weighted avg       0.97      0.98      0.98     19662
#
# ------------------------------
# Target:  military
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     19026
#            1       0.66      0.25      0.36       636
#
#     accuracy                           0.97     19662
#    macro avg       0.82      0.62      0.67     19662
# weighted avg       0.97      0.97      0.97     19662
#
# ------------------------------
# Target:  child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19662
#
#     accuracy                           1.00     19662
#    macro avg       1.00      1.00      1.00     19662
# weighted avg       1.00      1.00      1.00     19662
#
# ------------------------------
# Target:  water
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     18420
#            1       0.77      0.63      0.69      1242
#
#     accuracy                           0.96     19662
#    macro avg       0.87      0.81      0.84     19662
# weighted avg       0.96      0.96      0.96     19662
#
# ------------------------------
# Target:  food
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     17482
#            1       0.80      0.72      0.76      2180
#
#     accuracy                           0.95     19662
#    macro avg       0.88      0.85      0.87     19662
# weighted avg       0.95      0.95      0.95     19662
#
# ------------------------------
# Target:  shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     17936
#            1       0.80      0.52      0.63      1726
#
#     accuracy                           0.95     19662
#    macro avg       0.88      0.75      0.80     19662
# weighted avg       0.94      0.95      0.94     19662
#
# ------------------------------
# Target:  clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     19364
#            1       0.77      0.46      0.58       298
#
#     accuracy                           0.99     19662
#    macro avg       0.88      0.73      0.79     19662
# weighted avg       0.99      0.99      0.99     19662
#
# ------------------------------
# Target:  money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     19208
#            1       0.64      0.30      0.41       454
#
#     accuracy                           0.98     19662
#    macro avg       0.81      0.65      0.70     19662
# weighted avg       0.98      0.98      0.98     19662
#
# ------------------------------
# Target:  missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     19442
#            1       0.69      0.23      0.35       220
#
#     accuracy                           0.99     19662
#    macro avg       0.84      0.62      0.67     19662
# weighted avg       0.99      0.99      0.99     19662
#
# ------------------------------
# Target:  refugees
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     19006
#            1       0.62      0.24      0.34       656
#
#     accuracy                           0.97     19662
#    macro avg       0.80      0.62      0.66     19662
# weighted avg       0.96      0.97      0.96     19662
#
# ------------------------------
# Target:  death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18779
#            1       0.77      0.39      0.52       883
#
#     accuracy                           0.97     19662
#    macro avg       0.87      0.69      0.75     19662
# weighted avg       0.96      0.97      0.96     19662
#
# ------------------------------
# Target:  other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93     17068
#            1       0.56      0.11      0.18      2594
#
#     accuracy                           0.87     19662
#    macro avg       0.72      0.55      0.56     19662
# weighted avg       0.84      0.87      0.83     19662
#
# ------------------------------
# Target:  infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     18376
#            1       0.47      0.08      0.14      1286
#
#     accuracy                           0.93     19662
#    macro avg       0.71      0.54      0.55     19662
# weighted avg       0.91      0.93      0.91     19662
#
# ------------------------------
# Target:  transport
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18762
#            1       0.70      0.26      0.38       900
#
#     accuracy                           0.96     19662
#    macro avg       0.84      0.63      0.68     19662
# weighted avg       0.95      0.96      0.95     19662
#
# ------------------------------
# Target:  buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18664
#            1       0.71      0.37      0.49       998
#
#     accuracy                           0.96     19662
#    macro avg       0.84      0.68      0.74     19662
# weighted avg       0.95      0.96      0.95     19662
#
# ------------------------------
# Target:  electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     19262
#            1       0.70      0.18      0.29       400
#
#     accuracy                           0.98     19662
#    macro avg       0.84      0.59      0.64     19662
# weighted avg       0.98      0.98      0.98     19662
#
# ------------------------------
# Target:  tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     19545
#            1       0.56      0.09      0.15       117
#
#     accuracy                           0.99     19662
#    macro avg       0.78      0.54      0.57     19662
# weighted avg       0.99      0.99      0.99     19662
#
# ------------------------------
# Target:  hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     19445
#            1       0.34      0.07      0.11       217
#
#     accuracy                           0.99     19662
#    macro avg       0.67      0.53      0.55     19662
# weighted avg       0.98      0.99      0.98     19662
#
# ------------------------------
# Target:  shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19571
#            1       0.75      0.03      0.06        91
#
#     accuracy                           1.00     19662
#    macro avg       0.87      0.52      0.53     19662
# weighted avg       0.99      1.00      0.99     19662
#
# ------------------------------
# Target:  aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     19425
#            1       0.46      0.12      0.19       237
#
#     accuracy                           0.99     19662
#    macro avg       0.72      0.56      0.59     19662
# weighted avg       0.98      0.99      0.98     19662
#
# ------------------------------
# Target:  other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     18801
#            1       0.40      0.08      0.13       861
#
#     accuracy                           0.95     19662
#    macro avg       0.68      0.54      0.55     19662
# weighted avg       0.93      0.95      0.94     19662
#
# ------------------------------
# Target:  weather_related
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91     14171
#            1       0.88      0.61      0.72      5491
#
#     accuracy                           0.87     19662
#    macro avg       0.87      0.79      0.82     19662
# weighted avg       0.87      0.87      0.86     19662
#
# ------------------------------
# Target:  floods
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     18048
#            1       0.91      0.54      0.68      1614
#
#     accuracy                           0.96     19662
#    macro avg       0.93      0.77      0.83     19662
# weighted avg       0.96      0.96      0.95     19662
#
# ------------------------------
# Target:  storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     17810
#            1       0.77      0.45      0.57      1852
#
#     accuracy                           0.94     19662
#    macro avg       0.86      0.72      0.77     19662
# weighted avg       0.93      0.94      0.93     19662
#
# ------------------------------
# Target:  fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     19463
#            1       0.57      0.32      0.41       199
#
#     accuracy                           0.99     19662
#    macro avg       0.78      0.66      0.70     19662
# weighted avg       0.99      0.99      0.99     19662
#
# ------------------------------
# Target:  earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     17804
#            1       0.89      0.79      0.83      1858
#
#     accuracy                           0.97     19662
#    macro avg       0.93      0.89      0.91     19662
# weighted avg       0.97      0.97      0.97     19662
#
# ------------------------------
# Target:  cold
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     19245
#            1       0.68      0.32      0.43       417
#
#     accuracy                           0.98     19662
#    macro avg       0.83      0.66      0.71     19662
# weighted avg       0.98      0.98      0.98     19662
#
# ------------------------------
# Target:  other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     18611
#            1       0.56      0.18      0.27      1051
#
#     accuracy                           0.95     19662
#    macro avg       0.76      0.58      0.62     19662
# weighted avg       0.93      0.95      0.94     19662
#
# ------------------------------
# Target:  direct_report
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92     15925
#            1       0.73      0.45      0.56      3737
#
#     accuracy                           0.86     19662
#    macro avg       0.80      0.71      0.74     19662
# weighted avg       0.85      0.86      0.85     19662
#
# ------------------------------

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle

# %%
with open('classifier.pkl', 'wb') as f:
    pickle.dump(cv, f)

# %% [markdown]
# ### 10. Use this notebook to complete `train_classifier.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
