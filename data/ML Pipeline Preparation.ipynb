# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\luong\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
pd.set_option('display.max_colwidth', None)

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table("clean_disaster_data", engine)

# %%
X = df["message"]
y = df.iloc[:, 4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier

# %%
pipeline = Pipeline([
    ('text_pipeline', Pipeline([
        ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
        ('tfidf_transformer', TfidfTransformer())
    ])) ,
    ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
pipeline_fitted = pipeline.fit(X_train, y_train)
# Out:
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
from sklearn.metrics import classification_report

# %%
y_prediction_train = pipeline_fitted.predict(X_test)

# %%
for idx, column in enumerate(y.columns.values):
    print("Target: ", column)
    print(classification_report(y_test[column], y_prediction_train[:, idx]))
    print("---" * 10)
# Out:
# Target:  related
#               precision    recall  f1-score   support
#
#            0       0.65      0.33      0.44      1521
#            1       0.82      0.95      0.88      4986
#
#     accuracy                           0.80      6507
#    macro avg       0.74      0.64      0.66      6507
# weighted avg       0.78      0.80      0.78      6507
#
# ------------------------------
# Target:  request
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      5403
#            1       0.77      0.57      0.66      1104
#
#     accuracy                           0.90      6507
#    macro avg       0.85      0.77      0.80      6507
# weighted avg       0.89      0.90      0.89      6507
#
# ------------------------------
# Target:  offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6486
#            1       0.00      0.00      0.00        21
#
#     accuracy                           1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      0.99      6507
#
# ------------------------------
# Target:  aid_related
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80      3782
#            1       0.75      0.60      0.66      2725
#
#     accuracy                           0.75      6507
#    macro avg       0.75      0.73      0.73      6507
# weighted avg       0.75      0.75      0.74      6507
#
# ------------------------------
# Target:  medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      5956
#            1       0.63      0.28      0.39       551
#
#     accuracy                           0.93      6507
#    macro avg       0.78      0.63      0.68      6507
# weighted avg       0.91      0.93      0.91      6507
#
# ------------------------------
# Target:  medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6161
#            1       0.63      0.34      0.44       346
#
#     accuracy                           0.95      6507
#    macro avg       0.80      0.66      0.71      6507
# weighted avg       0.95      0.95      0.95      6507
#
# ------------------------------
# Target:  search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6319
#            1       0.54      0.18      0.27       188
#
#     accuracy                           0.97      6507
#    macro avg       0.76      0.59      0.63      6507
# weighted avg       0.96      0.97      0.97      6507
#
# ------------------------------
# Target:  security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6385
#            1       0.47      0.06      0.10       122
#
#     accuracy                           0.98      6507
#    macro avg       0.72      0.53      0.55      6507
# weighted avg       0.97      0.98      0.97      6507
#
# ------------------------------
# Target:  military
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6301
#            1       0.59      0.29      0.39       206
#
#     accuracy                           0.97      6507
#    macro avg       0.78      0.64      0.69      6507
# weighted avg       0.96      0.97      0.97      6507
#
# ------------------------------
# Target:  child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6507
#
#     accuracy                           1.00      6507
#    macro avg       1.00      1.00      1.00      6507
# weighted avg       1.00      1.00      1.00      6507
#
# ------------------------------
# Target:  water
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      6083
#            1       0.74      0.62      0.67       424
#
#     accuracy                           0.96      6507
#    macro avg       0.85      0.80      0.82      6507
# weighted avg       0.96      0.96      0.96      6507
#
# ------------------------------
# Target:  food
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5776
#            1       0.80      0.70      0.75       731
#
#     accuracy                           0.95      6507
#    macro avg       0.88      0.84      0.86      6507
# weighted avg       0.94      0.95      0.94      6507
#
# ------------------------------
# Target:  shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5936
#            1       0.76      0.57      0.65       571
#
#     accuracy                           0.95      6507
#    macro avg       0.86      0.78      0.81      6507
# weighted avg       0.94      0.95      0.94      6507
#
# ------------------------------
# Target:  clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6400
#            1       0.65      0.37      0.47       107
#
#     accuracy                           0.99      6507
#    macro avg       0.82      0.69      0.73      6507
# weighted avg       0.98      0.99      0.98      6507
#
# ------------------------------
# Target:  money
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6364
#            1       0.52      0.31      0.39       143
#
#     accuracy                           0.98      6507
#    macro avg       0.75      0.65      0.69      6507
# weighted avg       0.97      0.98      0.98      6507
#
# ------------------------------
# Target:  missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6445
#            1       0.50      0.13      0.21        62
#
#     accuracy                           0.99      6507
#    macro avg       0.75      0.56      0.60      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  refugees
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6277
#            1       0.64      0.24      0.35       230
#
#     accuracy                           0.97      6507
#    macro avg       0.80      0.62      0.67      6507
# weighted avg       0.96      0.97      0.96      6507
#
# ------------------------------
# Target:  death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6225
#            1       0.75      0.42      0.54       282
#
#     accuracy                           0.97      6507
#    macro avg       0.86      0.71      0.76      6507
# weighted avg       0.96      0.97      0.96      6507
#
# ------------------------------
# Target:  other_aid
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      5675
#            1       0.50      0.15      0.23       832
#
#     accuracy                           0.87      6507
#    macro avg       0.69      0.56      0.58      6507
# weighted avg       0.84      0.87      0.84      6507
#
# ------------------------------
# Target:  infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      6081
#            1       0.44      0.11      0.18       426
#
#     accuracy                           0.93      6507
#    macro avg       0.69      0.55      0.57      6507
# weighted avg       0.91      0.93      0.91      6507
#
# ------------------------------
# Target:  transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6223
#            1       0.70      0.19      0.29       284
#
#     accuracy                           0.96      6507
#    macro avg       0.83      0.59      0.64      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6175
#            1       0.66      0.40      0.50       332
#
#     accuracy                           0.96      6507
#    macro avg       0.81      0.69      0.74      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6387
#            1       0.42      0.17      0.25       120
#
#     accuracy                           0.98      6507
#    macro avg       0.70      0.59      0.62      6507
# weighted avg       0.97      0.98      0.98      6507
#
# ------------------------------
# Target:  tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6464
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6436
#            1       0.36      0.13      0.19        71
#
#     accuracy                           0.99      6507
#    macro avg       0.68      0.56      0.59      6507
# weighted avg       0.98      0.99      0.99      6507
#
# ------------------------------
# Target:  shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6469
#            1       0.00      0.00      0.00        38
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6422
#            1       0.21      0.06      0.09        85
#
#     accuracy                           0.98      6507
#    macro avg       0.60      0.53      0.54      6507
# weighted avg       0.98      0.98      0.98      6507
#
# ------------------------------
# Target:  other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6236
#            1       0.36      0.12      0.18       271
#
#     accuracy                           0.95      6507
#    macro avg       0.66      0.56      0.58      6507
# weighted avg       0.94      0.95      0.94      6507
#
# ------------------------------
# Target:  weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      4671
#            1       0.85      0.66      0.74      1836
#
#     accuracy                           0.87      6507
#    macro avg       0.86      0.80      0.83      6507
# weighted avg       0.87      0.87      0.86      6507
#
# ------------------------------
# Target:  floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5947
#            1       0.87      0.57      0.69       560
#
#     accuracy                           0.96      6507
#    macro avg       0.92      0.78      0.83      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      5897
#            1       0.74      0.53      0.62       610
#
#     accuracy                           0.94      6507
#    macro avg       0.85      0.76      0.79      6507
# weighted avg       0.93      0.94      0.93      6507
#
# ------------------------------
# Target:  fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6435
#            1       0.54      0.18      0.27        72
#
#     accuracy                           0.99      6507
#    macro avg       0.77      0.59      0.63      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  earthquake
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5903
#            1       0.90      0.73      0.81       604
#
#     accuracy                           0.97      6507
#    macro avg       0.94      0.86      0.90      6507
# weighted avg       0.97      0.97      0.97      6507
#
# ------------------------------
# Target:  cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6355
#            1       0.72      0.29      0.41       152
#
#     accuracy                           0.98      6507
#    macro avg       0.85      0.64      0.70      6507
# weighted avg       0.98      0.98      0.98      6507
#
# ------------------------------
# Target:  other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6173
#            1       0.44      0.13      0.20       334
#
#     accuracy                           0.95      6507
#    macro avg       0.70      0.56      0.59      6507
# weighted avg       0.93      0.95      0.93      6507
#
# ------------------------------
# Target:  direct_report
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5261
#            1       0.72      0.51      0.60      1246
#
#     accuracy                           0.87      6507
#    macro avg       0.80      0.73      0.76      6507
# weighted avg       0.86      0.87      0.86      6507
#
# ------------------------------

# %% [markdown]
# ### 6. Improve your model

# %% [markdown]
# Add another feature named __StartingVerb__

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %% [markdown]
# Create a new pipeline which union this new feature before putting it into the classifier algorithm

# %%
pipeline_new = Pipeline([
    ('feature', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
            ('tfidf_transformer', TfidfTransformer())
        ])),
        ('starting_verb', StartingVerbExtractor()) 
    ])) ,
    ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
])

# %% [markdown]
# Use grid search to find better parameters.

# %%
parameters =  {
    'classifier__estimator__learning_rate': [0.5, 1.0],
    'classifier__estimator__n_estimators': [10, 20]
}

cv = GridSearchCV(pipeline_new, param_grid=parameters, cv=5, n_jobs=-1, verbose=3) 

cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\luong\anaconda3\envs\analysis\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature',
#                                         FeatureUnion(transformer_list=[('text_pipeline',
#                                                                         Pipeline(steps=[('count_vectorizer',
#                                                                                          CountVectorizer(tokenizer=<function tokenize at 0x00000212405F09A0>)),
#                                                                                         ('tfidf_transformer',
#                                                                                          TfidfTransformer())])),
#                                                                        ('starting_verb',
#                                                                         StartingVerbExtractor())])),
#                                        ('classifier',
#                                         MultiOutputClassifier(estimator=AdaBoostClassifier()))]),
#              n_jobs=-1,
#              param_grid={'classifier__estimator__learning_rate': [0.5, 1.0],
#                          'classifier__estimator__n_estimators': [10, 20]},
#              verbose=3)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_prediction_train = cv.predict(X_test)

# %%
for idx, column in enumerate(y.columns.values):
    print("Target: ", column)
    print(classification_report(y_test[column], y_prediction_train[:, idx]))
    print("---" * 10)
# Out:
# Target:  related
#               precision    recall  f1-score   support
#
#            0       0.65      0.30      0.41      1521
#            1       0.82      0.95      0.88      4986
#
#     accuracy                           0.80      6507
#    macro avg       0.73      0.62      0.64      6507
# weighted avg       0.78      0.80      0.77      6507
#
# ------------------------------
# Target:  request
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      5403
#            1       0.76      0.54      0.63      1104
#
#     accuracy                           0.89      6507
#    macro avg       0.83      0.75      0.78      6507
# weighted avg       0.88      0.89      0.88      6507
#
# ------------------------------
# Target:  offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6486
#            1       0.00      0.00      0.00        21
#
#     accuracy                           1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      0.99      6507
#
# ------------------------------
# Target:  aid_related
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79      3782
#            1       0.74      0.56      0.64      2725
#
#     accuracy                           0.73      6507
#    macro avg       0.73      0.71      0.71      6507
# weighted avg       0.73      0.73      0.73      6507
#
# ------------------------------
# Target:  medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      5956
#            1       0.63      0.29      0.39       551
#
#     accuracy                           0.93      6507
#    macro avg       0.78      0.64      0.68      6507
# weighted avg       0.91      0.93      0.91      6507
#
# ------------------------------
# Target:  medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6161
#            1       0.68      0.33      0.44       346
#
#     accuracy                           0.96      6507
#    macro avg       0.82      0.66      0.71      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6319
#            1       0.58      0.20      0.29       188
#
#     accuracy                           0.97      6507
#    macro avg       0.78      0.60      0.64      6507
# weighted avg       0.97      0.97      0.97      6507
#
# ------------------------------
# Target:  security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6385
#            1       0.39      0.06      0.10       122
#
#     accuracy                           0.98      6507
#    macro avg       0.69      0.53      0.55      6507
# weighted avg       0.97      0.98      0.97      6507
#
# ------------------------------
# Target:  military
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6301
#            1       0.61      0.22      0.33       206
#
#     accuracy                           0.97      6507
#    macro avg       0.79      0.61      0.66      6507
# weighted avg       0.96      0.97      0.96      6507
#
# ------------------------------
# Target:  child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6507
#
#     accuracy                           1.00      6507
#    macro avg       1.00      1.00      1.00      6507
# weighted avg       1.00      1.00      1.00      6507
#
# ------------------------------
# Target:  water
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      6083
#            1       0.73      0.62      0.67       424
#
#     accuracy                           0.96      6507
#    macro avg       0.85      0.80      0.83      6507
# weighted avg       0.96      0.96      0.96      6507
#
# ------------------------------
# Target:  food
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5776
#            1       0.80      0.69      0.74       731
#
#     accuracy                           0.95      6507
#    macro avg       0.88      0.83      0.85      6507
# weighted avg       0.94      0.95      0.94      6507
#
# ------------------------------
# Target:  shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5936
#            1       0.77      0.54      0.63       571
#
#     accuracy                           0.95      6507
#    macro avg       0.86      0.76      0.80      6507
# weighted avg       0.94      0.95      0.94      6507
#
# ------------------------------
# Target:  clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6400
#            1       0.71      0.48      0.57       107
#
#     accuracy                           0.99      6507
#    macro avg       0.85      0.74      0.78      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6364
#            1       0.57      0.27      0.36       143
#
#     accuracy                           0.98      6507
#    macro avg       0.78      0.63      0.68      6507
# weighted avg       0.97      0.98      0.98      6507
#
# ------------------------------
# Target:  missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6445
#            1       0.60      0.15      0.23        62
#
#     accuracy                           0.99      6507
#    macro avg       0.80      0.57      0.61      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6277
#            1       0.61      0.20      0.30       230
#
#     accuracy                           0.97      6507
#    macro avg       0.79      0.60      0.64      6507
# weighted avg       0.96      0.97      0.96      6507
#
# ------------------------------
# Target:  death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6225
#            1       0.73      0.38      0.50       282
#
#     accuracy                           0.97      6507
#    macro avg       0.85      0.69      0.74      6507
# weighted avg       0.96      0.97      0.96      6507
#
# ------------------------------
# Target:  other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      5675
#            1       0.49      0.10      0.16       832
#
#     accuracy                           0.87      6507
#    macro avg       0.69      0.54      0.55      6507
# weighted avg       0.83      0.87      0.83      6507
#
# ------------------------------
# Target:  infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6081
#            1       0.47      0.10      0.17       426
#
#     accuracy                           0.93      6507
#    macro avg       0.71      0.55      0.57      6507
# weighted avg       0.91      0.93      0.91      6507
#
# ------------------------------
# Target:  transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6223
#            1       0.69      0.16      0.26       284
#
#     accuracy                           0.96      6507
#    macro avg       0.83      0.58      0.62      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6175
#            1       0.72      0.37      0.49       332
#
#     accuracy                           0.96      6507
#    macro avg       0.84      0.68      0.74      6507
# weighted avg       0.95      0.96      0.95      6507
#
# ------------------------------
# Target:  electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6387
#            1       0.47      0.15      0.23       120
#
#     accuracy                           0.98      6507
#    macro avg       0.73      0.57      0.61      6507
# weighted avg       0.97      0.98      0.98      6507
#
# ------------------------------
# Target:  tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6464
#            1       0.17      0.02      0.04        43
#
#     accuracy                           0.99      6507
#    macro avg       0.58      0.51      0.52      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6436
#            1       0.20      0.08      0.12        71
#
#     accuracy                           0.99      6507
#    macro avg       0.59      0.54      0.56      6507
# weighted avg       0.98      0.99      0.98      6507
#
# ------------------------------
# Target:  shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6469
#            1       0.25      0.03      0.05        38
#
#     accuracy                           0.99      6507
#    macro avg       0.62      0.51      0.52      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6422
#            1       0.43      0.07      0.12        85
#
#     accuracy                           0.99      6507
#    macro avg       0.71      0.53      0.56      6507
# weighted avg       0.98      0.99      0.98      6507
#
# ------------------------------
# Target:  other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6236
#            1       0.45      0.08      0.14       271
#
#     accuracy                           0.96      6507
#    macro avg       0.71      0.54      0.56      6507
# weighted avg       0.94      0.96      0.94      6507
#
# ------------------------------
# Target:  weather_related
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      4671
#            1       0.86      0.63      0.73      1836
#
#     accuracy                           0.87      6507
#    macro avg       0.86      0.80      0.82      6507
# weighted avg       0.87      0.87      0.86      6507
#
# ------------------------------
# Target:  floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5947
#            1       0.88      0.55      0.68       560
#
#     accuracy                           0.95      6507
#    macro avg       0.92      0.77      0.83      6507
# weighted avg       0.95      0.95      0.95      6507
#
# ------------------------------
# Target:  storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      5897
#            1       0.72      0.46      0.56       610
#
#     accuracy                           0.93      6507
#    macro avg       0.83      0.72      0.76      6507
# weighted avg       0.93      0.93      0.93      6507
#
# ------------------------------
# Target:  fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6435
#            1       0.41      0.25      0.31        72
#
#     accuracy                           0.99      6507
#    macro avg       0.70      0.62      0.65      6507
# weighted avg       0.99      0.99      0.99      6507
#
# ------------------------------
# Target:  earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5903
#            1       0.90      0.76      0.83       604
#
#     accuracy                           0.97      6507
#    macro avg       0.94      0.88      0.90      6507
# weighted avg       0.97      0.97      0.97      6507
#
# ------------------------------
# Target:  cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6355
#            1       0.80      0.26      0.39       152
#
#     accuracy                           0.98      6507
#    macro avg       0.89      0.63      0.69      6507
# weighted avg       0.98      0.98      0.98      6507
#
# ------------------------------
# Target:  other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6173
#            1       0.51      0.17      0.26       334
#
#     accuracy                           0.95      6507
#    macro avg       0.73      0.58      0.62      6507
# weighted avg       0.93      0.95      0.94      6507
#
# ------------------------------
# Target:  direct_report
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      5261
#            1       0.73      0.47      0.57      1246
#
#     accuracy                           0.87      6507
#    macro avg       0.81      0.71      0.75      6507
# weighted avg       0.85      0.87      0.85      6507
#
# ------------------------------

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle

# %%
with open('classifier.pkl', 'wb') as f:
    pickle.dump(cv, f)

# %% [markdown]
# ### 10. Use this notebook to complete `train_classifier.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
